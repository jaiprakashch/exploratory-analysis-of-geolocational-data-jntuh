# %%
import json
import pandas as pd
from pandas.io.json import json_normalize
import requests
from tabulate import tabulate
from sklearn.cluster import KMeans
import random
import numpy as np
import pandas as pd
import folium
import warnings
warnings.filterwarnings('ignore')
import os
os.environ.keys()
# Out:
# KeysView(environ({'SHELL': '/bin/bash', 'NV_LIBCUBLAS_VERSION': '11.11.3.6-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'COLAB_JUPYTER_TRANSPORT': 'ipc', 'NV_NVML_DEV_VERSION': '11.8.86-1', 'NV_CUDNN_PACKAGE_NAME': 'libcudnn8', 'CGROUP_MEMORY_EVENTS': '/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events', 'NV_LIBNCCL_DEV_PACKAGE': 'libnccl-dev=2.15.5-1+cuda11.8', 'NV_LIBNCCL_DEV_PACKAGE_VERSION': '2.15.5-1', 'VM_GCE_METADATA_HOST': '169.254.169.253', 'HOSTNAME': '508f9c7cf7cb', 'LANGUAGE': 'en_US', 'TBE_RUNTIME_ADDR': '172.28.0.1:8011', 'GCE_METADATA_TIMEOUT': '3', 'NVIDIA_REQUIRE_CUDA': 'cuda>=11.8 brand=tesla,driver>=470,driver<471 brand=unknown,driver>=470,driver<471 brand=nvidia,driver>=470,driver<471 brand=nvidiartx,driver>=470,driver<471 brand=geforce,driver>=470,driver<471 brand=geforcertx,driver>=470,driver<471 brand=quadro,driver>=470,driver<471 brand=quadrortx,driver>=470,driver<471 brand=titan,driver>=470,driver<471 brand=titanrtx,driver>=470,driver<471', 'NV_LIBCUBLAS_DEV_PACKAGE': 'libcublas-dev-11-8=11.11.3.6-1', 'NV_NVTX_VERSION': '11.8.86-1', 'COLAB_JUPYTER_IP': '172.28.0.12', 'NV_CUDA_CUDART_DEV_VERSION': '11.8.89-1', 'NV_LIBCUSPARSE_VERSION': '11.7.5.86-1', 'COLAB_LANGUAGE_SERVER_PROXY_ROOT_URL': 'http://172.28.0.1:8013/', 'NV_LIBNPP_VERSION': '11.8.0.86-1', 'NCCL_VERSION': '2.15.5-1', 'KMP_LISTEN_PORT': '6000', 'TF_FORCE_GPU_ALLOW_GROWTH': 'true', 'ENV': '/root/.bashrc', 'PWD': '/', 'COLAB_LANGUAGE_SERVER_PROXY_REQUEST_TIMEOUT': '30s', 'TBE_EPHEM_CREDS_ADDR': '172.28.0.1:8009', 'TBE_CREDS_ADDR': '172.28.0.1:8008', 'NV_CUDNN_PACKAGE': 'libcudnn8=8.9.6.50-1+cuda11.8', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'COLAB_JUPYTER_TOKEN': '', 'LAST_FORCED_REBUILD': '20231105', 'NV_NVPROF_DEV_PACKAGE': 'cuda-nvprof-11-8=11.8.87-1', 'NV_LIBNPP_PACKAGE': 'libnpp-11-8=11.8.0.86-1', 'NV_LIBNCCL_DEV_PACKAGE_NAME': 'libnccl-dev', 'TCLLIBPATH': '/usr/share/tcltk/tcllib1.20', 'NV_LIBCUBLAS_DEV_VERSION': '11.11.3.6-1', 'NVIDIA_PRODUCT_NAME': 'CUDA', 'COLAB_KERNEL_MANAGER_PROXY_HOST': '172.28.0.12', 'NV_LIBCUBLAS_DEV_PACKAGE_NAME': 'libcublas-dev-11-8', 'NV_CUDA_CUDART_VERSION': '11.8.89-1', 'COLAB_WARMUP_DEFAULTS': '1', 'HOME': '/root', 'LANG': 'en_US.UTF-8', 'COLUMNS': '100', 'CUDA_VERSION': '11.8.0', 'CLOUDSDK_CONFIG': '/content/.config', 'NV_LIBCUBLAS_PACKAGE': 'libcublas-11-8=11.11.3.6-1', 'NV_CUDA_NSIGHT_COMPUTE_DEV_PACKAGE': 'cuda-nsight-compute-11-8=11.8.0-1', 'COLAB_RELEASE_TAG': 'release-colab_20231110-060112_RC00', 'KMP_TARGET_PORT': '9000', 'KMP_EXTRA_ARGS': '--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https://colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/m-s-2wxpvpiw448as --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true', 'NV_LIBNPP_DEV_PACKAGE': 'libnpp-dev-11-8=11.8.0.86-1', 'COLAB_LANGUAGE_SERVER_PROXY_LSP_DIRS': '/datalab/web/pyright/typeshed-fallback/stdlib,/usr/local/lib/python3.10/dist-packages', 'NV_LIBCUBLAS_PACKAGE_NAME': 'libcublas-11-8', 'COLAB_KERNEL_MANAGER_PROXY_PORT': '6000', 'CLOUDSDK_PYTHON': 'python3', 'NV_LIBNPP_DEV_VERSION': '11.8.0.86-1', 'NO_GCE_CHECK': 'False', 'PYTHONPATH': '/env/python', 'NV_LIBCUSPARSE_DEV_VERSION': '11.7.5.86-1', 'LIBRARY_PATH': '/usr/local/cuda/lib64/stubs', 'NV_CUDNN_VERSION': '8.9.6.50', 'SHLVL': '0', 'NV_CUDA_LIB_VERSION': '11.8.0-1', 'COLAB_LANGUAGE_SERVER_PROXY': '/usr/colab/bin/language_service', 'NVARCH': 'x86_64', 'NV_CUDNN_PACKAGE_DEV': 'libcudnn8-dev=8.9.6.50-1+cuda11.8', 'NV_CUDA_COMPAT_PACKAGE': 'cuda-compat-11-8', 'NV_LIBNCCL_PACKAGE': 'libnccl2=2.15.5-1+cuda11.8', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib:/usr/local/nvidia/lib64', 'COLAB_GPU': '', 'NV_CUDA_NSIGHT_COMPUTE_VERSION': '11.8.0-1', 'GCS_READ_CACHE_BLOCK_SIZE_MB': '16', 'NV_NVPROF_VERSION': '11.8.87-1', 'LC_ALL': 'en_US.UTF-8', 'COLAB_FILE_HANDLER_ADDR': 'localhost:3453', 'PATH': '/opt/bin:/usr/ ...

# %%
url = 'https://discover.search.hereapi.com/v1/discover?in=circle:17.4933,78.3914;r=20000&q=apartment&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'
data = requests.get(url).json()
d=json_normalize(data['items'])
d.to_csv('apartment.csv')
d
# Out:
#                                    title  \
# 0                    Shri Sai Brindavana
# 1                         Sujana Enclave
# 2                     Sai Satyam Enclave
# 3                   Shri Datta Residency
# 4                     Prashanthi Nilayam
# 5                         Tejaswi Towers
# 6                        P. S Bose Abode
# 7   Shiva Shakti's Dharani Sai Residency
# 8                                 Anjani
# 9                       Sai Balaji Tower
# 10              Shri Sai Chaitanya Vihar
# 11                           R. K. Villa
# 12                  Sankhla's H C Towers
# 13                       Vinjamoor Nivas
# 14                       Deepika Nilayam
# 15                    Lakshmi's Nandanam
# 16                    Vasundhara Nilayam
# 17                          Masters Home
# 18                          Atluri Nivas
# 19               Shri Sai Anurag Nilayam
#
#                                                    id language  \
# 0   here:pds:place:356jx7ps-a5e5743dc61509f4cc1846...    en-GB
# 1   here:pds:place:356jx7ps-6168a67a87d90a93720e0d...    en-GB
# 2   here:pds:place:356jx7ps-f5e403e68b8a069e28ab02...    en-GB
# 3   here:pds:place:356jx7ps-a0242c395d7e0f48053596...    en-GB
# 4   here:pds:place:356jx7ps-82fb3e221038038eef5bd6...    en-GB
# 5   here:pds:place:356jx7ps-717be43b8f1a0aa748e3c2...    en-GB
# 6   here:pds:place:356jx7ps-c345fb6ed24f0788b6a01b...    en-GB
# 7   here:pds:place:356jx7ps-5628674ca5e602e58cf5ff...    en-GB
# 8   here:pds:place:356jx7ps-ac5724565f7b09d9a9067a...    en-GB
# 9   here:pds:place:356jx7ps-02eca2a09b850f9ca3cccb...    en-GB
# 10  here:pds:place:356jx7ps-7b2d8e16317f0d7f0dc08f...    en-GB
# 11  here:pds:place:356jx7ps-3e6c5cbc58d904e16230ac...    en-GB
# 12  here:pds:place:356jx7ps-d01b9b71f096054b67137f...    en-GB
# 13  here:pds:place:356jx7ps-5b7399d53eb607bd6d9587...    en-GB
# 14  here:pds:place:356jx7ps-5b97c471ba290c5341a963...    en-GB
# 15  here:pds:place:356jx7ps-aadee181ce3903bf15e97f...    en-GB
# 16  here:pds:place:356jx7ps-df0a9a09b7a90f4e2f4bbf...    en-GB
# 17  here:pds:place:356jx7ps-3df4be0c148d09c53c9b3a...    en-GB
# 18  here:pds:place:356jx7ps-44b64bb0204806057ed5f7...    en-GB
# 19  here:pds:place:356jx7ps-e24a7fb906c70c51e7d48f...    en-GB
#
#                                        ontologyId resultType  \
# 0   here:cm:ontology:apartment_rental_flat_rental      place
# 1   here:cm:ontology:apartment_rental_flat_rental      place
# 2   here:cm:ontology:apartment_rental_flat_rental      place
# 3   here:cm:ontology:apartment_rental_flat_rental      place
# 4   here:cm:ontology:apartment_rental_flat_rental      place
# 5   here:cm:ontology:apartment_rental_flat_rental      place
# 6   here:cm:ontology:apartment_rental_flat_rental      place
# 7   here:cm:ontology:apartment_rental_flat_rental      place
# 8   here:cm:ontology:apartment_rental_flat_rental      place
# 9   here:cm:ontology:apartment_rental_flat_rental      place
# 10  here:cm:ontology:apartment_rental_flat_rental      place
# 11  here:cm:ontology:apartment_rental_flat_rental      place
# 12  here:cm:ontology:apartment_rental_flat_rental      place
# 13  here:cm:ontology:apartment_rental_flat_rental      place
# 14  here:cm:ontology:apartment_rental_flat_rental      place
# 15  here:cm:ontology:apartment_rental_flat_rental      place
# 16  here:cm:ontology:apartment_rental_flat_rental      place
# 17  here:cm:ontology:apartment_rental_flat_rental      place
# 18  here:cm:ontology:apartment_rental_flat_rental      place
# 19  here:cm:ontology:apartment_rental_flat_rental      place
#
#                                   access  distance  \
# 0   [{'lat': 17.48947, 'lng': 78.38926}]       483
# 1   [{'lat': 17.48895, 'lng': 78.38927}]       519
# 2   [{'lat': 17.48932, 'lng': 78.38865}]       533
# 3   [{'lat': 17.49069, 'lng': 78.38662}]       576
# 4    [{'lat': 17.4897, 'lng': 78.38725}]       606
# 5   [{'lat': 17.48784, 'lng': 78.38963}]       633
# 6     [{'lat': 17.493, 'lng': 78.38505}]       671
# 7    [{'lat': 17.48924, 'lng': 78.3867}]       686
# 8   [{'lat': 17.49285, 'lng': 78.38493}]       686
# 9   [{'lat': 17.49928, 'lng': 78.39316}]       687
# 10  [{'lat': 17.49038, 'lng': 78.38575}]       690
# 11  [{'lat': 17.49806, 'lng': 78.39625}]       732
# 12  [{'lat': 17.49694, 'lng': 78.39718}]       739
# 13   [{'lat': 17.4912, 'lng': 78.38483}]       740
# 14  [{'lat': 17.49931, 'lng': 78.39461}]       746
# 15  [{'lat': 17.48804, 'lng': 78.38681}]       747
# 16   [{'lat': 17.49148, 'lng': 78.3845}]       751
# 17  [{'lat': 17.49931, 'lng': 78.39473}]       752
# 18  [{'lat': 17.49582, 'lng': 78.38466}]       771
# 19  [{'lat': 17.49329, 'lng': 78.38416}]       778
#
#                                            categories  \
# 0   [{'id': '900-9300-0221', 'name': 'Residential ...
# 1   [{'id': '900-9300-0221', 'name': 'Residential ...
# 2   [{'id': '900-9300-0221', 'name': 'Residential ...
# 3   [{'id': '900-9300-0221', 'name': 'Residential ...
# 4   [{'id': '900-9300-0221', 'name': 'Residential ...
# 5   [{'id': '900-9300-0221', 'name': 'Residential ...
# 6   [{'id': '900-9300-0221', 'name': 'Residential ...
# 7   [{'id': '900-9300-0221', 'name': 'Residential ...
# 8   [{'id': '900-9300-0221', 'name': 'Residential ...
# 9   [{'id': '900-9300-0221', 'name': 'Residential ...
# 10  [{'id': '900-9300-0221', 'name': 'Residential ...
# 11  [{'id': '900-9300-0221', 'name': 'Residential ...
# 12  [{'id': '900-9300-0221', 'name': 'Residential ...
# 13  [{'id': '900-9300-0221', 'name': 'Residential ...
# 14  [{'id': '900-9300-0221', 'name': 'Residential ...
# 15  [{'id': '900-9300-0221', 'name': 'Residential ...
# 16  [{'id': '900-9300-0221', 'name': 'Residential ...
# 17  [{'id': '900-9300-0221', 'name': 'Residential ...
# 18  [{'id': '900-9300-0221', 'name': 'Residential ...
# 19  [{'id': '900-9300-0221', 'name': 'Residential ...
#
#                                            references  \
# 0   [{'supplier': {'id': 'core'}, 'id': '106990958...
# 1   [{'supplier': {'id': 'core'}, 'id': '106990973...
# 2   [{'supplier': {'id': 'core'}, 'id': '111040877...
# 3   [{'supplier': {'id': 'core'}, 'id': '106990972...
# 4   [{'supplier': {'id': 'core'}, 'id': '106990945...
# 5   [{'supplier': {'id': 'core'}, 'id': '106990958...
# 6   [{'supplier': {'id': 'core'}, 'id': '109724116...
# 7   [{'supplier': {'id': 'core'}, 'id': '106990975...
# 8   [{'supplier': {'id': 'core'}, 'id': '109724127...
# 9   [{'supplier': {'id': 'core'}, 'id': '112263675...
# 10  [{'supplier': {'id': 'core'}, 'id': '109724159...
# 11  [{'supplier': {'id': 'core'}, 'id': '109724121...
# 12  [{'supplier': {'id': 'core'}, 'id': '112263597...
# 13  [{'supplier': {'id': 'core'}, 'id': '109724137...
# 14  [{'supplier': {'id': 'core'}, 'id': '109724149...
# 15  [{'supplier': {'id': 'core'}, 'id': '111041400...
# 16  [{'supplier': {'id': 'core'}, 'id': '109724137...
# 17  [{'supplier': {'id': 'core'}, 'id': '109724149...
# 18  [{'supplier': {'id': 'core'}, 'id': '106995252...
# 19  [{'supplier': {'id': 'core'}, 'id': '109724139...
#
#                                         address.label  ... address.state  \
# 0   Shri Sai Brindavana, KPHB Clny-6th Phase, Kuka...  ...     Telangana
# 1   Sujana Enclave, KPHB Clny-6th Phase-Hig, Kukat...  ...     Telangana
# 2   Sai Satyam Enclave, KPHB Clny-6th Phase, Kukat...  ...     Telangana
# 3   Shri Datta Residency, KPHB Clny, Kukatpally, H...  ...     Telangana
# 4   Prashanthi Nilayam, KPHB Clny-6th Phase, Kukat...  ...     Telangana
# 5   Tejaswi Towers, KPHB Clny-6th Phase-Hig, Kukat...  ...     Telangana
# 6   P. S Bose Abode, Bhagat Singh Nagar Road, Vasa...  ...     Telangana
# 7   Shiva Shakti's Dharani Sai Residency, K P H B ...  ...     Telangana
# 8   Anjani, Bhagat Singh Nagar Road, Vasanth NGR, ...  ...     Telangana
# 9   Sai Balaji Tower, Nannaya Road, Jal Vayu Vihar...  ...     Telangana
# 10  Shri Sai Chaitanya Vihar, KPHB Clny, Kukatpall...  ...     Telangana
# 11  R. K. Villa, No 3 Street, Jal Vayu Vihar-Weste...  ...     Telangana
# 12  Sankhla's H C Towers, No 1 Street, Jal Vayu Vi...  ...     Telangana
# 13  Vinjamoor Nivas, KPHB Clny, Kukatpally, Hydera...  ...     Telangana
# 14  Deepika Nilayam, No 5 Street, Jal Vayu Vihar-W...  ...     Telangana
# 15  Lakshmi's Nandanam, KPHB Clny-6th Phase-Hig, K...  ...     Telangana
# 16  Vasundhara Nilayam, KPHB Clny, Kukatpally, Hyd...  ...     Telangana
# 17  Masters Home, No 5 Street, Jal Vayu Vihar-West...  ...     Telangana
# 18  Atluri Nivas, Vasanth NGR, Kukatpally, Hyderab...  ...     Telangana
# 19  Shri Sai Anurag Nilayam, Vasanth NGR, Kukatpal...  ...     Telangana
#
#         address.county address.city address.district  \
# 0   Medchal Malkajgiri    Hyderabad       Kukatpally
# 1   Medchal Malkajgiri    Hyderabad       Kukatpally
# 2   Medchal Malkajgiri    Hyderabad       Kukatpally
# 3   Medchal Malkajgiri    Hyderabad       Kukatpally
# 4   Medchal Malkajgiri    Hyderabad       Kukatpally
# 5   Medchal Malkajgiri    Hyderabad       Kukatpally
# 6   Medchal Malkajgiri    Hyderabad       Kukatpally
# 7   Medchal Malkajgiri    Hyderabad       Kukatpally
# 8   Medchal Malkajgiri    Hyderabad       Kukatpally
# 9   Medchal Malkajgiri    Hyderabad       Kukatpally
# 10  Medchal Malkajgiri    Hyderabad       Kukatpally
# 11  Medchal Malkajgiri    Hyderabad       Kukatpally
# 12  Medchal Malkajgiri    Hyderabad       Kukatpally
# 13  Medchal Malkajgiri    Hyderabad       Kukatpally
# 14  Medchal Malkajgiri    Hyderabad       Kukatpally
# 15  Medchal Malkajgiri    Hyderabad       Kukatpally
# 16  Medchal Malkajgiri    Hyderabad       Kukatpally
# 17  Medchal Malkajgiri    Hyderabad       Kukatpally
# 18  Medchal Malkajgiri    Hyderabad       Kukatpally
# 19  Medchal Malkajgiri    Hyderabad       Kukatpally
#
#              address.subdistrict address.postalCode position.lat position.lng  \
# 0            KPHB Clny-6th Phase             500085     17.48948     78.38923
# 1        KPHB Clny-6th Phase-Hig             500085     17.48907     78.38933
# 2            KPHB Clny-6th Phase             500085     17.48937     78.38852
# 3                      KPHB Clny             500085     17.49080     78.38664
# 4            KPHB Clny-6th Phase             500085     17.48960     78.38720
# 5        KPHB Clny-6th Phase-Hig             500085     17.48790     78.38950
# 6                    Vasanth NGR             500085     17.49297     78.38508
# 7            KPHB Clny-6th Phase             500085     17.48919     78.38658
# 8                    Vasanth NGR             500085     17.49284     78.38495
# 9   Jal Vayu Vihar-Western Hills             500072     17.49925     78.39316
# 10                     KPHB Clny             500085     17.49036     78.38567
# 11  Jal Vayu Vihar-Western Hills             500072     17.49800     78.39623
# 12  Jal Vayu Vihar-Western Hills             500072     17.49704     78.39716
# 13                     KPHB Clny             500085     17.49131     78.38474
# 14  Jal Vayu Vihar-Western Hills             500072     17.49927     78.39461
# 15       KPHB Clny-6th Phase-Hig             500085     17.48811     78.38693
# 16                     KPHB Clny             500085     17.49144     78.38459
# 17  Jal Vayu Vihar-Western Hills             500072     17.49927     78.39473
# 18                   Vasanth NGR             500085     17.49582     78.38463
# 19                   Vasanth NGR             500085     17.49344     78.38407
#
#              address.street                                    chains
# 0                       NaN                                       NaN
# 1                       NaN                                       NaN
# 2                       NaN                                       NaN
# 3                       NaN                                       NaN
# 4                       NaN                                       NaN
# 5                       NaN                                       NaN
# 6   Bhagat Singh Nagar Road                                       NaN
# 7    K P H B 6th Phase Road                                       NaN
# 8   Bhagat Singh Nagar Road                                       NaN
# 9              Nannaya Road                                       NaN
# 10                      NaN  [{'id': '28281', 'name': 'A&O reality'}]
# 11              No 3 Street                                       NaN
# 12              No 1 Street                                       NaN
# 13                      NaN                                       NaN
# 14              No 5 Street                                       NaN
# 15                      NaN                                       NaN
# 16                      NaN                                       NaN
# 17              No 5 Street                                       NaN
# 18                      NaN                                       NaN
# 19                      NaN                                       NaN
#
# [20 rows x 23 columns]

# %%
d2=d[['title','address.label','distance','access','position.lat','position.lng','address.postalCode','id']]
d2.to_csv('cleaned_apartment.csv')
d2
# Out:
#                                    title  \
# 0                    Shri Sai Brindavana
# 1                         Sujana Enclave
# 2                     Sai Satyam Enclave
# 3                   Shri Datta Residency
# 4                     Prashanthi Nilayam
# 5                         Tejaswi Towers
# 6                        P. S Bose Abode
# 7   Shiva Shakti's Dharani Sai Residency
# 8                                 Anjani
# 9                       Sai Balaji Tower
# 10              Shri Sai Chaitanya Vihar
# 11                           R. K. Villa
# 12                  Sankhla's H C Towers
# 13                       Vinjamoor Nivas
# 14                       Deepika Nilayam
# 15                    Lakshmi's Nandanam
# 16                    Vasundhara Nilayam
# 17                          Masters Home
# 18                          Atluri Nivas
# 19               Shri Sai Anurag Nilayam
#
#                                         address.label  distance  \
# 0   Shri Sai Brindavana, KPHB Clny-6th Phase, Kuka...       483
# 1   Sujana Enclave, KPHB Clny-6th Phase-Hig, Kukat...       519
# 2   Sai Satyam Enclave, KPHB Clny-6th Phase, Kukat...       533
# 3   Shri Datta Residency, KPHB Clny, Kukatpally, H...       576
# 4   Prashanthi Nilayam, KPHB Clny-6th Phase, Kukat...       606
# 5   Tejaswi Towers, KPHB Clny-6th Phase-Hig, Kukat...       633
# 6   P. S Bose Abode, Bhagat Singh Nagar Road, Vasa...       671
# 7   Shiva Shakti's Dharani Sai Residency, K P H B ...       686
# 8   Anjani, Bhagat Singh Nagar Road, Vasanth NGR, ...       686
# 9   Sai Balaji Tower, Nannaya Road, Jal Vayu Vihar...       687
# 10  Shri Sai Chaitanya Vihar, KPHB Clny, Kukatpall...       690
# 11  R. K. Villa, No 3 Street, Jal Vayu Vihar-Weste...       732
# 12  Sankhla's H C Towers, No 1 Street, Jal Vayu Vi...       739
# 13  Vinjamoor Nivas, KPHB Clny, Kukatpally, Hydera...       740
# 14  Deepika Nilayam, No 5 Street, Jal Vayu Vihar-W...       746
# 15  Lakshmi's Nandanam, KPHB Clny-6th Phase-Hig, K...       747
# 16  Vasundhara Nilayam, KPHB Clny, Kukatpally, Hyd...       751
# 17  Masters Home, No 5 Street, Jal Vayu Vihar-West...       752
# 18  Atluri Nivas, Vasanth NGR, Kukatpally, Hyderab...       771
# 19  Shri Sai Anurag Nilayam, Vasanth NGR, Kukatpal...       778
#
#                                   access  position.lat  position.lng  \
# 0   [{'lat': 17.48947, 'lng': 78.38926}]      17.48948      78.38923
# 1   [{'lat': 17.48895, 'lng': 78.38927}]      17.48907      78.38933
# 2   [{'lat': 17.48932, 'lng': 78.38865}]      17.48937      78.38852
# 3   [{'lat': 17.49069, 'lng': 78.38662}]      17.49080      78.38664
# 4    [{'lat': 17.4897, 'lng': 78.38725}]      17.48960      78.38720
# 5   [{'lat': 17.48784, 'lng': 78.38963}]      17.48790      78.38950
# 6     [{'lat': 17.493, 'lng': 78.38505}]      17.49297      78.38508
# 7    [{'lat': 17.48924, 'lng': 78.3867}]      17.48919      78.38658
# 8   [{'lat': 17.49285, 'lng': 78.38493}]      17.49284      78.38495
# 9   [{'lat': 17.49928, 'lng': 78.39316}]      17.49925      78.39316
# 10  [{'lat': 17.49038, 'lng': 78.38575}]      17.49036      78.38567
# 11  [{'lat': 17.49806, 'lng': 78.39625}]      17.49800      78.39623
# 12  [{'lat': 17.49694, 'lng': 78.39718}]      17.49704      78.39716
# 13   [{'lat': 17.4912, 'lng': 78.38483}]      17.49131      78.38474
# 14  [{'lat': 17.49931, 'lng': 78.39461}]      17.49927      78.39461
# 15  [{'lat': 17.48804, 'lng': 78.38681}]      17.48811      78.38693
# 16   [{'lat': 17.49148, 'lng': 78.3845}]      17.49144      78.38459
# 17  [{'lat': 17.49931, 'lng': 78.39473}]      17.49927      78.39473
# 18  [{'lat': 17.49582, 'lng': 78.38466}]      17.49582      78.38463
# 19  [{'lat': 17.49329, 'lng': 78.38416}]      17.49344      78.38407
#
#    address.postalCode                                                 id
# 0              500085  here:pds:place:356jx7ps-a5e5743dc61509f4cc1846...
# 1              500085  here:pds:place:356jx7ps-6168a67a87d90a93720e0d...
# 2              500085  here:pds:place:356jx7ps-f5e403e68b8a069e28ab02...
# 3              500085  here:pds:place:356jx7ps-a0242c395d7e0f48053596...
# 4              500085  here:pds:place:356jx7ps-82fb3e221038038eef5bd6...
# 5              500085  here:pds:place:356jx7ps-717be43b8f1a0aa748e3c2...
# 6              500085  here:pds:place:356jx7ps-c345fb6ed24f0788b6a01b...
# 7              500085  here:pds:place:356jx7ps-5628674ca5e602e58cf5ff...
# 8              500085  here:pds:place:356jx7ps-ac5724565f7b09d9a9067a...
# 9              500072  here:pds:place:356jx7ps-02eca2a09b850f9ca3cccb...
# 10             500085  here:pds:place:356jx7ps-7b2d8e16317f0d7f0dc08f...
# 11             500072  here:pds:place:356jx7ps-3e6c5cbc58d904e16230ac...
# 12             500072  here:pds:place:356jx7ps-d01b9b71f096054b67137f...
# 13             500085  here:pds:place:356jx7ps-5b7399d53eb607bd6d9587...
# 14             500072  here:pds:place:356jx7ps-5b97c471ba290c5341a963...
# 15             500085  here:pds:place:356jx7ps-aadee181ce3903bf15e97f...
# 16             500085  here:pds:place:356jx7ps-df0a9a09b7a90f4e2f4bbf...
# 17             500072  here:pds:place:356jx7ps-3df4be0c148d09c53c9b3a...
# 18             500085  here:pds:place:356jx7ps-44b64bb0204806057ed5f7...
# 19             500085  here:pds:place:356jx7ps-e24a7fb906c70c51e7d48f...

# %%
df_final=d2[['position.lat','position.lng']]

CafeList=[]
ResList=[]
GymList=[]
latitudes = list(d2['position.lat'])
longitudes = list( d2['position.lng'])
for lat, lng in zip(latitudes, longitudes):
    radius = '1000' #Set the radius to 1000 metres
    latitude=lat
    longitude=lng

    search_query = 'cafe' #Search for any cafes
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    CafeList.append(venues['title'].count())

    search_query = 'gym' #Search for any gyms
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    GymList.append(venues['title'].count())

    search_query = 'restaurents' #search for supermarkets
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    ResList.append(venues['title'].count())

df_final['Cafes'] = CafeList
df_final['Restaurents'] = ResList
df_final['Gyms'] = GymList

df_final
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms
# 0       17.48948      78.38923     10           20    15
# 1       17.48907      78.38933     10           20    14
# 2       17.48937      78.38852     10           20    14
# 3       17.49080      78.38664     10           20    13
# 4       17.48960      78.38720      9           20    11
# 5       17.48790      78.38950     10           20    13
# 6       17.49297      78.38508      4           20    12
# 7       17.48919      78.38658      9           20    11
# 8       17.49284      78.38495      4           20    12
# 9       17.49925      78.39316      6           20     8
# 10      17.49036      78.38567      8           20    11
# 11      17.49800      78.39623     10           20     9
# 12      17.49704      78.39716     10           20     9
# 13      17.49131      78.38474      8           20    12
# 14      17.49927      78.39461      6           20     8
# 15      17.48811      78.38693      8           20    12
# 16      17.49144      78.38459      7           20    12
# 17      17.49927      78.39473      6           20     8
# 18      17.49582      78.38463      4           20    11
# 19      17.49344      78.38407      2           20    11

# %%
kclusters = 3

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_final)
df_final['Cluster']=kmeans.labels_
df_final['Cluster']=df_final['Cluster'].apply(str)
df_final
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms Cluster
# 0       17.48948      78.38923     10           20    15       1
# 1       17.48907      78.38933     10           20    14       1
# 2       17.48937      78.38852     10           20    14       1
# 3       17.49080      78.38664     10           20    13       1
# 4       17.48960      78.38720      9           20    11       1
# 5       17.48790      78.38950     10           20    13       1
# 6       17.49297      78.38508      4           20    12       2
# 7       17.48919      78.38658      9           20    11       1
# 8       17.49284      78.38495      4           20    12       2
# 9       17.49925      78.39316      6           20     8       0
# 10      17.49036      78.38567      8           20    11       1
# 11      17.49800      78.39623     10           20     9       0
# 12      17.49704      78.39716     10           20     9       0
# 13      17.49131      78.38474      8           20    12       1
# 14      17.49927      78.39461      6           20     8       0
# 15      17.48811      78.38693      8           20    12       1
# 16      17.49144      78.38459      7           20    12       1
# 17      17.49927      78.39473      6           20     8       0
# 18      17.49582      78.38463      4           20    11       2
# 19      17.49344      78.38407      2           20    11       2

# %%
map_bom=folium.Map(location=[17.4933,78.3914],zoom_start=12)

# instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()

# set color scheme for the clusters
def color_producer(cluster):
    if cluster=='0':
        return 'green'
    elif cluster=='1':
        return 'blue'
    else:
        return 'orange'

latitudes = list(df_final['position.lat'])
longitudes = list(df_final['position.lng'])
labels = list(df_final['Cluster'])
names=list(d2['title'])
for lat, lng, label,names in zip(latitudes, longitudes, labels,names):
    folium.CircleMarker(
            [lat,lng],
            fill=True,
            fill_opacity=1,
            popup=folium.Popup(names, max_width = 300),
            radius=8,
            color=color_producer(label)
        ).add_to(map_bom)

# add locations to map
map_bom.add_child(locations)
folium.Marker([17.4933,78.3914],popup='JNTUH').add_to(map_bom)

# %%
map_bom.save("map-jntuHYDERABAD.html")
